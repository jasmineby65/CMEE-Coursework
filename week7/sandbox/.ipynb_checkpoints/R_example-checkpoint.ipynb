# %%
a <- "this is R!"; cat(a)
# Out:
# this is R!

# %%
require(ggplot2)
library(repr) # resizing plots within jupyter
options(repr.plot.width=10, repr.plot.height=7)

x <- seq(0,5,0.1); y <- sin(x)
qplot(x,y, geom="line")
# Out:
# plot without title
